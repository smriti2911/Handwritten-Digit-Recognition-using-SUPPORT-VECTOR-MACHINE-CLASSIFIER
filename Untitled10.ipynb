# %%
import numpy as np
from sklearn.datasets import load_digits

# %%
dataset=load_digits()

# %%
print(dataset.data)
print (dataset.target)

print(dataset.data.shape)
print(dataset.images.shape)

dataimageLength=len(dataset.images)
print(dataimageLength)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]
# (1797, 64)
# (1797, 8, 8)
# 1797

# %%
n=2
import matplotlib.pyplot as plt
plt.gray()
plt.matshow(dataset.images[n])
plt.show()
dataset.images[n]
# Out:
# array([[ 0.,  0.,  0.,  4., 15., 12.,  0.,  0.],
#        [ 0.,  0.,  3., 16., 15., 14.,  0.,  0.],
#        [ 0.,  0.,  8., 13.,  8., 16.,  0.,  0.],
#        [ 0.,  0.,  1.,  6., 15., 11.,  0.,  0.],
#        [ 0.,  1.,  8., 13., 15.,  1.,  0.,  0.],
#        [ 0.,  9., 16., 16.,  5.,  0.,  0.,  0.],
#        [ 0.,  3., 13., 16., 16., 11.,  5.,  0.],
#        [ 0.,  0.,  0.,  3., 11., 16.,  9.,  0.]])

# %%
x=dataset.images.reshape((dataimageLength,-1))
x
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
y=dataset.target
y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
print(x_train.shape)
print(x_test.shape)
# Out:
# (1347, 64)
# (450, 64)

# %%
from sklearn import svm
model=svm.SVC(kernel='linear')
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
n=-1
result=model.predict(dataset.images[n].reshape((1,-1)))
plt.imshow(dataset.images[n], cmap=plt.cm.gray_r, interpolation='nearest')
print(result)
print("/n")
plt.axis('off')
plt.title('Prediction: %i' % result)
plt.show()
# Out:
# [8]
# /n
# <ipython-input-21-5ffd96aa971a>:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title('Prediction: %i' % result)

# %%
y_pred= model.predict(x_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[2 2]
#  [8 8]
#  [2 2]
#  [6 6]
#  [6 6]
#  [7 7]
#  [1 1]
#  [9 9]
#  [8 8]
#  [5 5]
#  [2 2]
#  [8 8]
#  [6 6]
#  [6 6]
#  [6 6]
#  [6 6]
#  [1 1]
#  [0 0]
#  [5 5]
#  [8 8]
#  [8 8]
#  [7 7]
#  [8 8]
#  [4 4]
#  [7 7]
#  [5 5]
#  [4 4]
#  [9 9]
#  [2 2]
#  [9 9]
#  [4 4]
#  [7 7]
#  [6 6]
#  [8 8]
#  [9 9]
#  [4 4]
#  [3 3]
#  [1 1]
#  [0 0]
#  [1 1]
#  [8 8]
#  [6 6]
#  [7 7]
#  [7 7]
#  [1 1]
#  [0 0]
#  [7 7]
#  [6 6]
#  [2 2]
#  [1 1]
#  [9 9]
#  [6 6]
#  [7 7]
#  [9 9]
#  [0 0]
#  [0 0]
#  [5 5]
#  [1 1]
#  [6 6]
#  [3 3]
#  [0 0]
#  [2 2]
#  [3 3]
#  [4 4]
#  [1 1]
#  [9 9]
#  [2 2]
#  [6 6]
#  [9 9]
#  [1 1]
#  [8 8]
#  [3 3]
#  [5 5]
#  [1 1]
#  [2 2]
#  [8 8]
#  [2 2]
#  [2 2]
#  [9 9]
#  [7 7]
#  [2 2]
#  [3 3]
#  [6 6]
#  [0 0]
#  [5 5]
#  [3 3]
#  [7 7]
#  [5 5]
#  [1 1]
#  [2 2]
#  [9 9]
#  [9 9]
#  [3 3]
#  [1 1]
#  [7 7]
#  [7 7]
#  [4 4]
#  [8 8]
#  [5 5]
#  [8 8]
#  [5 5]
#  [5 5]
#  [2 2]
#  [5 5]
#  [9 9]
#  [0 0]
#  [7 7]
#  [1 1]
#  [4 4]
#  [4 7]
#  [3 3]
# ...

# %%
from sklearn.metrics import accuracy_score
print("accuracy of the model:{0}%", format(accuracy_score(y_test,y_pred)*100))
# Out:
# accuracy of the model:{0}% 97.11111111111111

# %%
from sklearn import svm
model1=svm.SVC(kernel='linear')
model2=svm.SVC(kernel='rbf')
model3=svm.SVC(gamma=0.001)

model1.fit(x_train,y_train)
model2.fit(x_train,y_train)
model3.fit(x_train,y_train)

y_predModel1=model1.predict(x_test)
y_predModel2=model2.predict(x_test)
y_predModel3=model3.predict(x_test)

print("accuracy of the model1:{0}%", format(accuracy_score(y_test,y_predModel1)*100))
print("accuracy of the model2:{0}%", format(accuracy_score(y_test,y_predModel2)*100))
print("accuracy of the model3:{0}%", format(accuracy_score(y_test,y_predModel3)*100))
# Out:
# accuracy of the model1:{0}% 97.11111111111111
# accuracy of the model2:{0}% 99.11111111111111
# accuracy of the model3:{0}% 99.55555555555556

# %%
# Calculate accuracy for each model
accuracy1 = accuracy_score(y_test, y_predModel1) * 100
accuracy2 = accuracy_score(y_test, y_predModel2) * 100
accuracy3 = accuracy_score(y_test, y_predModel3) * 100

# List of model names and corresponding accuracies
models = ['Linear Kernel', 'RBF Kernel', 'Gamma=0.001']
accuracies = [accuracy1, accuracy2, accuracy3]

# Plotting the accuracies
plt.figure(figsize=(8, 5))
plt.bar(models, accuracies, color=['blue', 'green', 'orange'])
plt.xlabel('SVM Model')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy of Different SVM Models')
plt.ylim(0, 100)  # Set the y-axis limit for better visualization
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95)  # Retain 95% variance
x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10],
    'gamma': [0.001, 0.01, 0.1],
    'kernel': ['rbf', 'poly']
}
grid_search = GridSearchCV(svm.SVC(), param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.001, 0.01, 0.1],
#                          'kernel': ['rbf', 'poly']},
#              scoring='accuracy')

# %%
model = svm.SVC(class_weight='balanced')
